# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('swiggy_data.xlsx')

# %%
df.head()
# Out:
#      ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  4607     INDORES13DEL02                   37                      4.9
# 1  B379     BANGRES18DEL02                   34                      4.5
# 2  5D6D     BANGRES19DEL01                   23                      4.4
# 3  7A6A    COIMBRES13DEL02                   38                      4.7
# 4  70A2     CHENRES12DEL01                   32                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude Type_of_order Type_of_vehicle  Time_taken(min)
# ...

# %%
df.shape
# Out:
# (45593, 11)

# %%
df.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Type_of_order', 'Type_of_vehicle',
#        'Time_taken(min)'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Type_of_order                  0
# Type_of_vehicle                0
# Time_taken(min)                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45593 entries, 0 to 45592
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45593 non-null  object
#  1   Delivery_person_ID           45593 non-null  str
#  2   Delivery_person_Age          45593 non-null  int64
#  3   Delivery_person_Ratings      45593 non-null  float64
#  4   Restaurant_latitude          45593 non-null  float64
#  5   Restaurant_longitude         45593 non-null  float64
#  6   Delivery_location_latitude   45593 non-null  float64
#  7   Delivery_location_longitude  45593 non-null  float64
#  8   Type_of_order                45593 non-null  str
#  9   Type_of_vehicle              45593 non-null  str
#  10  Time_taken(min)              45593 non-null  int64
# dtypes: float64(5), int64(2), object(1), str(3)
# memory usage: 3.8+ MB

# %%
df.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# count         45593.000000             45593.000000         45593.000000
# mean             29.544075                 4.632367            17.017729
# std               5.696793                 0.327708             8.185109
# min              15.000000                 1.000000           -30.905562
# 25%              25.000000                 4.600000            12.933284
# 50%              29.000000                 4.700000            18.546947
# 75%              34.000000                 4.800000            22.728163
# max              50.000000                 6.000000            30.914057
#
#        Restaurant_longitude  Delivery_location_latitude  \
# count          45593.000000                45593.000000
# mean              70.231332                   17.465186
# std               22.883647                    7.335122
# min              -88.366217                    0.010000
# ...

# %%
df.sample(20)
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 35071   789      JAPRES04DEL01                   24                      4.8
# 16401  A111   RANCHIRES12DEL01                   23                      4.8
# 8949   5DD8      JAPRES04DEL03                   33                      3.7
# 10290  B4F8     INDORES14DEL02                   23                      5.0
# 28939  4613      HYDRES02DEL01                   29                      4.8
# 45535  3781      JAPRES13DEL03                   35                      4.9
# 23943  1C83     BANGRES08DEL01                   38                      4.3
# 11565  8226      MYSRES03DEL03                   31                      4.0
# 118    3EC5   RANCHIRES01DEL03                   20                      4.9
# 33879  2828      HYDRES16DEL03                   36                      4.8
# 39503  C9E0      KOLRES19DEL01                   29                      4.1
# ...

# %%
(df == "NaN").sum()
# Out:
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Type_of_order                  0
# Type_of_vehicle                0
# Time_taken(min)                0
# dtype: int64

# %% [markdown]
# no null values

# %%
import missingno as msno
msno.matrix(df)
# Out:
# <Axes: >

# %%
msno.bar(df)
# Out:
# <Axes: >

# %%
msno.heatmap(df)
# Out:
# d:\swiggy\swigenv\Lib\site-packages\seaborn\matrix.py:309: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# d:\swiggy\swigenv\Lib\site-packages\seaborn\matrix.py:309: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# <Axes: >

# %% [markdown]
# ### here there is no missing values since, no coreation btweeen the missing values

# %%
msno.dendrogram(df)
# Out:
# d:\swiggy\swigenv\Lib\site-packages\scipy\cluster\hierarchy.py:2950: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set_ylim([dvw, 0])
# <Axes: >

# %%
df.head()
# Out:
#      ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  4607     INDORES13DEL02                   37                      4.9
# 1  B379     BANGRES18DEL02                   34                      4.5
# 2  5D6D     BANGRES19DEL01                   23                      4.4
# 3  7A6A    COIMBRES13DEL02                   38                      4.7
# 4  70A2     CHENRES12DEL01                   32                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude Type_of_order Type_of_vehicle  Time_taken(min)
# ...

# %% [markdown]
# ### Delivery Person Id

# %% [markdown]
# extract the city name of the city from the rider

# %%
(
  df['Delivery_person_ID'].str.split("RES").str.get(0).rename("city_name")
)
# Out:
# 0          INDO
# 1          BANG
# 2          BANG
# 3         COIMB
# 4          CHEN
#           ...
# 45588       JAP
# 45589       AGR
# 45590      CHEN
# 45591     COIMB
# 45592    RANCHI
# Name: city_name, Length: 45593, dtype: object

# %% [markdown]
# ### Delivery Person Age

# %%
df['Delivery_person_Age'].astype(float).describe()
# Out:
# count    45593.000000
# mean        29.544075
# std          5.696793
# min         15.000000
# 25%         25.000000
# 50%         29.000000
# 75%         34.000000
# max         50.000000
# Name: Delivery_person_Age, dtype: float64

# %% [markdown]
# the main  concern here  is that 25 is consiedred as minor

# %%
sns.boxplot(df['Delivery_person_Age'])
# Out:
# <Axes: ylabel='Delivery_person_Age'>

# %%
minor_age =df.loc[df['Delivery_person_Age'].astype('float') <  18]

# %%
minor_age
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 2387    564      JAPRES15DEL03                   15                      1.0
# 2905    CD0    INDORES010DEL03                   15                      1.0
# 2951    91A      SURRES17DEL03                   15                      1.0
# 5902    474     CHENRES15DEL03                   15                      1.0
# 9156    73F     BANGRES05DEL01                   15                      1.0
# 10900  1B49      MUMRES14DEL02                   15                      1.0
# 11125   40B      SURRES12DEL01                   15                      1.0
# 12093   523     INDORES03DEL02                   15                      1.0
# 15124  18B0   RANCHIRES02DEL01                   15                      1.0
# 15927   550     CHENRES08DEL02                   15                      1.0
# 16084   58C      MUMRES02DEL01                   15                      1.0
# ...

# %%
minor_age.value_counts().sum()
# Out:
# np.int64(38)

# %%
minor_age['Type_of_vehicle'].value_counts()
# Out:
# Type_of_vehicle
# scooter              13
# electric_scooter     13
# bicycle               8
# motorcycle            4
# Name: count, dtype: int64

# %% [markdown]
# ### Delivery person Ratings

# %%
df['Delivery_person_Ratings'].describe()
# Out:
# count    45593.000000
# mean         4.632367
# std          0.327708
# min          1.000000
# 25%          4.600000
# 50%          4.700000
# 75%          4.800000
# max          6.000000
# Name: Delivery_person_Ratings, dtype: float64

# %% [markdown]
# here  we  see that ratings is 6 which is not technically positive

# %%
sns.boxplot(df['Delivery_person_Ratings'])
# Out:
# <Axes: ylabel='Delivery_person_Ratings'>

# %% [markdown]
# it seems that there is lot of error

# %% [markdown]
# lets find out those rows which has ratings of 6

# %%
six_star_rating = df.loc[df['Delivery_person_Ratings'] == 6]
print(len(six_star_rating))
six_star_rating
# Out:
# 53
#                ID Delivery_person_ID  Delivery_person_Age  \
# 3586          46D     BANGRES05DEL01                   50
# 4714          493      HYDRES17DEL01                   50
# 5169          4F2      JAPRES08DEL01                   50
# 5362          430     BANGRES19DEL01                   50
# 5651     BEF 1.00      AGRRES13DEL02                   50
# 6394          427      JAPRES06DEL02                   50
# 7031          3EB      MYSRES15DEL02                   50
# 7681          D42      VADRES09DEL01                   50
# 9499          3F0    BANGRES010DEL01                   50
# 9535          3EF   RANCHIRES13DEL01                   50
# 10100         5B0      MYSRES04DEL01                   50
# 10737        BFFC      DEHRES18DEL02                   50
# 12297         940      SURRES02DEL02                   50
# 13257         490    COIMBRES03DEL02                   50
# 13652         434   RANCHIRES01DEL02                   50
# ...
